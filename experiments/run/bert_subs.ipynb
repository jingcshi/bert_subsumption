# %%
import torch
import numpy as np
import pandas as pd
import json
from tqdm import tqdm
from random import sample, shuffle, randrange
from datetime import datetime
from pybay.bert import EBertModel, EBertForSequenceClassification, EBertTokenizer, EBertForMaskedLM
from transformers import AutoModel, AutoModelForSequenceClassification, AutoTokenizer, AutoModelForMaskedLM, TrainingArguments, Trainer
from datasets import Dataset, load_metric, concatenate_datasets, DownloadConfig,load_dataset
from data import preprocess as prep
from experiments import breadcrumb as bc, box_experiments
from data.box_embedding import taxonomy_sampling
from torch.utils.data import RandomSampler, DataLoader, Subset
tokenizer = AutoTokenizer.from_pretrained('/data/ebay/data/jingcshi/bert-base-cased/', model_max_length=512)
clsmodel = AutoModelForSequenceClassification.from_pretrained('/data/ebay/data/jingcshi/bert-base-cased/').to('cuda:0')
maskmodel = AutoModelForMaskedLM.from_pretrained('/data/ebay/data/jingcshi/bert-base-cased/').to('cuda:0')
# Out:
# AllenNLP not available. Registrable won't work.
# Some weights of the model checkpoint at /data/ebay/data/jingcshi/bert-base-cased/ were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /data/ebay/data/jingcshi/bert-base-cased/ and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at /data/ebay/data/jingcshi/bert-base-cased/ were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
cattree = prep.load_ebay_taxonomy({'data':{'raw_taxonomy_path': './data/2021-10-12', 'breadcrumb_link': 'id'}},pandas=False)
classlist = prep.load_ebay_taxonomy({'data':{'raw_taxonomy_path': './data/2021-10-12', 'breadcrumb_link': 'symbol'}},pandas=True)
catid_table = {}
breadcrumb_table = {}
for i,row in classlist.iterrows():
    catid_table[row['catid']] = i
    breadcrumb_table[row['catid']] = row['breadcrumb']

# %%
#raw_data = taxonomy_sampling.informed_sampling(cattree, breadcrumb_table, transitive=False, relax=2, save_dir='./data/box_embedding/taxonomy5.csv')
raw_data = pd.read_csv('./data/box_embedding/taxonomy5.csv',dtype={'cat1':str,'cat2':str,'label':np.int64}).dropna()

# %%
def breadcrumb_prep_m(bc):
    segs = bc.replace(', ',' and ').replace('&','and').split(' > ')
    shuffle(segs)
    text = 'A category of products defined by: ' + segs[0]
    if len(segs) > 1:
        for s in segs[1:]:
            text += ', '
            text += s
    return text + '.'

# %%
def breadcrumb_prep_k(breadcrumb):
    text = breadcrumb[0]
    return text[:14] + 'commercial ' + text[14:]

# %%
data_mb = pd.read_csv('./data/train/fine_tune_data_modified_breadcrumbs_and.csv')
data_kw = pd.read_csv('./data/train/fine_tune_data_keywords.csv')
data_kw['cat1'] = data_kw.apply(lambda row: breadcrumb_prep_k([row['cat1']]), axis=1)
data_kw['cat2'] = data_kw.apply(lambda row: breadcrumb_prep_k([row['cat2']]), axis=1)
#data_kw.to_csv('./data/train/fine_tune_data_altkeywords.csv',index=False)
#data_mb.to_csv('/data/ebay/notebooks/jingcshi/Curation/data/train/fine_tune_data_modified_breadcrumbs_and.csv',index=False)

# %%
training_mb = Dataset.from_pandas(data_mb).shuffle(seed=1729)
training_kw = Dataset.from_pandas(data_kw).shuffle(seed=1729)

# %%
def tokenize(tokenizer, raw, return_tensors=None):
    return tokenizer(raw["cat1"], raw["cat2"], padding='max_length', truncation=True, return_tensors=return_tensors, max_length=96)

# %%
BATCH_SIZE = 16
LEARNING_RATE = 5e-6
NUM_EPOCHS = 5
#tokenized_mb = training_mb.map(lambda x: tokenize(tokenizer, x), batched=True, batch_size=BATCH_SIZE).remove_columns(['cat1','cat2'])
tokenized_kw = training_kw.map(lambda x: tokenize(tokenizer, x), batched=True, batch_size=BATCH_SIZE).remove_columns(['cat1','cat2'])
#eval_mb = tokenized_mb.train_test_split(test_size=0.05)['test']
eval_kw = tokenized_kw.train_test_split(test_size=0.05)['test']
# Out:
#   0%|          | 0/10534 [00:00<?, ?ba/s]

# %%
dlcfg = DownloadConfig(proxies={'http':'http://httpproxy.vip.ebay.com:80','https':'http://httpproxy.vip.ebay.com:80'})
metric = load_metric("f1",download_config=dlcfg)

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# %%
#training_args_mb = TrainingArguments("./utils/bert/ebert_trainer_mb", per_device_train_batch_size = BATCH_SIZE, num_train_epochs = NUM_EPOCHS, evaluation_strategy="epoch", learning_rate = LEARNING_RATE)
#trainer_mb = Trainer(model=clsmodel, args=training_args_mb, train_dataset=tokenized_mb, eval_dataset=eval_mb, compute_metrics=compute_metrics)
training_args_kw = TrainingArguments("./utils/bert/ebert_trainer_kw", per_device_train_batch_size = BATCH_SIZE, num_train_epochs = NUM_EPOCHS, evaluation_strategy="epoch", learning_rate = LEARNING_RATE)
trainer_kw = Trainer(model=clsmodel, args=training_args_kw, train_dataset=tokenized_kw, eval_dataset=eval_kw, compute_metrics=compute_metrics)

# %%
trainer_kw.train()
# Out:
# ***** Running training *****
#   Num examples = 168540
#   Num Epochs = 5
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 52670
#     <div>
#
#       <progress value='52670' max='52670' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [52670/52670 1:45:02, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000400</td>
#       <td>0.003100</td>
#       <td>0.997630</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.002800</td>
#       <td>0.000735</td>
#       <td>0.999407</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000700</td>
#       <td>0.000626</td>
#       <td>0.999407</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.001100</td>
#       <td>0.000135</td>
#       <td>0.999407</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000700</td>
#       <td>0.000001</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-1000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-1000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-1500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-1500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-1500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-2000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-2000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-2000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-2500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-2500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-2500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-3000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-3000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-3000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-3500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-3500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-3500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-4000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-4000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-4000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-4500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-4500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-4500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-5000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-5000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-5000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-5500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-5500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-5500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-6000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-6000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-6000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-6500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-6500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-6500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-7000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-7000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-7000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-7500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-7500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-7500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-8000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-8000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-8000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-8500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-8500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-8500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-9000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-9000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-9000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-9500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-9500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-9500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-10000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-10000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-10000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-10500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-10500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-10500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 8427
#   Batch size = 8
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-11000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-11000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-11000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-11500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-11500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-11500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-12000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-12000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-12000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-12500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-12500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-12500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-13000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-13000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-13000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-13500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-13500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-13500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-14000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-14000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-14000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-14500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-14500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-14500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-15000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-15000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-15000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-15500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-15500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-15500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-16000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-16000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-16000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-16500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-16500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-16500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-17000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-17000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-17000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-17500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-17500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-17500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-18000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-18000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-18000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-18500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-18500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-18500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-19000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-19000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-19000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-19500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-19500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-19500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-20000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-20000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-20000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-20500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-20500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-20500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-21000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-21000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-21000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 8427
#   Batch size = 8
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-21500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-21500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-21500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-22000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-22000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-22000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-22500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-22500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-22500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-23000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-23000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-23000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-23500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-23500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-23500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-24000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-24000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-24000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-24500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-24500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-24500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-25000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-25000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-25000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-25500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-25500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-25500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-26000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-26000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-26000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-26500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-26500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-26500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-27000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-27000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-27000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-27500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-27500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-27500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-28000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-28000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-28000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-29000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-29000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-29000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-29500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-29500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-29500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-30000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-30000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-30000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-30500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-30500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-30500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-31000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-31000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-31000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-31500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-31500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-31500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 8427
#   Batch size = 8
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-32000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-32000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-32000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-32500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-32500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-32500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-33000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-33000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-33000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-33500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-33500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-33500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-34000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-34000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-34000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-34500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-34500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-34500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-35000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-35000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-35000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-35500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-35500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-35500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-36000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-36000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-36000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-36500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-36500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-36500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-37000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-37000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-37000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-37500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-37500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-37500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-38000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-38000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-38000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-38500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-38500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-38500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-39000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-39000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-39000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-39500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-39500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-39500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-40000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-40000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-40000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-40500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-40500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-40500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-41000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-41000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-41000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-41500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-41500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-41500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-42000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-42000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-42000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 8427
#   Batch size = 8
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-42500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-42500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-42500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-43000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-43000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-43000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-43500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-43500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-43500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-44000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-44000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-44000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-44500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-44500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-44500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-45000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-45000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-45000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-45500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-45500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-45500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-46000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-46000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-46000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-46500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-46500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-46500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-47000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-47000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-47000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-47500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-47500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-47500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-48000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-48000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-48000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-48500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-48500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-48500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-49000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-49000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-49000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-49500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-49500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-49500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-50000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-50000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-50000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-50500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-50500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-50500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-51000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-51000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-51000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-51500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-51500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-51500/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-52000
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-52000/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-52000/pytorch_model.bin
# Saving model checkpoint to ./utils/bert/ebert_trainer_kw/checkpoint-52500
# Configuration saved in ./utils/bert/ebert_trainer_kw/checkpoint-52500/config.json
# Model weights saved in ./utils/bert/ebert_trainer_kw/checkpoint-52500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 8427
#   Batch size = 8
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=52670, training_loss=0.002353950238801767, metrics={'train_runtime': 6303.1334, 'train_samples_per_second': 133.695, 'train_steps_per_second': 8.356, 'total_flos': 4.1573191190976e+16, 'train_loss': 0.002353950238801767, 'epoch': 5.0})

# %%
now = datetime.now().strftime('%Y%m%d-%H%M')
clsmodel.save_pretrained(f'/data/ebay/notebooks/jingcshi/Curation/utils/bert/{now}')
# Out:
# Configuration saved in /data/ebay/notebooks/jingcshi/Curation/utils/bert/20220708-1709/config.json
# Model weights saved in /data/ebay/notebooks/jingcshi/Curation/utils/bert/20220708-1709/pytorch_model.bin

# %%
input_mb = tokenize(tokenizer,training_mb[157042],return_tensors='pt').to('cuda:0')
torch.softmax(clsmodel(**input_mb).logits.detach().cpu(),dim=1).numpy()
# Out:
# array([[2.8772837e-07, 9.9999976e-01]], dtype=float32)

# %%
training_kw[157042]
# Out:
# {'cat1': 'A category of commercial products defined by: business, industrial, cable, conduit, equipment, electrical, block.',
#  'cat2': 'A category of commercial products defined by: block, electrical, business, industrial, cable, conduit, equipment.',
#  'label': 1}

# %%
testdata = pd.read_csv('./data/test/subclass_golden_set.csv').dropna().astype({'cat1':str,'cat2':str})
validcats = list(catid_table.keys())
for i,row in testdata.iterrows():
    if str(row['cat1']) not in validcats or str(row['cat2']) not in validcats:
        testdata = testdata.drop([i])

# %%
THRESHOLD = 0.5
#clsmodel = EBertForSequenceClassification.from_pretrained('/data/ebay/notebooks/jingcshi/Curation/utils/bert/20220706-1751/').to('cuda:0')
confusion = {'y': np.array([],dtype=np.int32), 'y_pred': np.array([],dtype=np.int32)}
for _, row in testdata.iterrows():
    confusion['y'] = np.append(confusion['y'], row['label_loose'])
    inputs = tokenizer(breadcrumb_prep_k(breadcrumb_table[row['cat1']]),breadcrumb_prep_k(breadcrumb_table[row['cat2']]), padding='max_length', truncation=True, return_tensors='pt', max_length=96).to('cuda:0')                                                                                 
    pred = (torch.softmax(clsmodel(**inputs).logits.detach(),dim=1).cpu()[:,1] >= THRESHOLD).view(-1)
    confusion['y_pred'] = np.append(confusion['y_pred'], pred)
testresult = testdata
testresult['prediction'] = confusion['y_pred']
test_cm = box_experiments.build_confusion_matrix(confusion)
print(f'Test results:')
display(test_cm)
display(testresult)
# Out:
# Test results:
#                   F1=0.7136, precision=0.5547, recall=1.0000
#                                          Predict subsumption Predict negative
# Label subsumption                                         71                0
# Label negative                                            57                0
#        cat1    cat2  label_loose  label_strict  prediction
# 0     13756  261979            0             0           1
# 1     13756  261981            0             0           1
# 2     13756  261983            0             0           1
# 3     13756  261984            0             0           1
# 4    261979  261983            0             0           1
# ..      ...     ...          ...           ...         ...
# 131   22966  118985            0             0           1
# 132  261658   32884            1             0           1
# 133  118985   33034            1             1           1
# 134  262366   36028            1             0           1
# 135   50129  262421            1             1           1
#
# [128 rows x 5 columns]

# %%
raw_data
# Out:
#           cat1    cat2  label
# 0       175708   14969      1
# 1        41404  180008      1
# 2       119120  185209      1
# 3       261780  261833      1
# 4          799   13623      1
# ...        ...     ...    ...
# 168535     136   16091      0
# 168536   32810   48094      0
# 168537   37964   19177      0
# 168538    3123  258749      0
# 168539  259284   33011      0
#
# [168540 rows x 3 columns]

# %%
data_kw
# Out:
#                                                      cat1  \
# 0       A category of commercial products defined by: ...
# 1       A category of commercial products defined by: ...
# 2       A category of commercial products defined by: ...
# 3       A category of commercial products defined by: ...
# 4       A category of commercial products defined by: ...
# ...                                                   ...
# 168535  A category of commercial products defined by: ...
# 168536  A category of commercial products defined by: ...
# 168537  A category of commercial products defined by: ...
# 168538  A category of commercial products defined by: ...
# 168539  A category of commercial products defined by: ...
#
#                                                      cat2  label
# 0       A category of commercial products defined by: ...      1
# 1       A category of commercial products defined by: ...      1
# 2       A category of commercial products defined by: ...      1
# 3       A category of commercial products defined by: ...      1
# 4       A category of commercial products defined by: ...      1
# ...                                                   ...    ...
# 168535  A category of commercial products defined by: ...      0
# 168536  A category of commercial products defined by: ...      0
# 168537  A category of commercial products defined by: ...      0
# 168538  A category of commercial products defined by: ...      0
# 168539  A category of commercial products defined by: ...      0
#
# [168540 rows x 3 columns]
